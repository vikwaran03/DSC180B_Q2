# %%
import torch
import random
import torch_geometric
from torch_geometric import utils
from scipy.sparse import coo_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import rbf_kernel

from torch_geometric.utils import degree, to_networkx
from torch_geometric.nn.models import Node2Vec

from itertools import combinations
from scipy.stats import mannwhitneyu
from scipy.stats import kruskal

import networkx as nx
import matplotlib.patches as mpatches

# %%
seed = 0

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
ec_full_hic = np.load('data/GBM39ec_5k_collapsed_matrix.npy')
hsr_full_hic = np.load('data/GBM39HSR_5k_collapsed_matrix.npy')

# %%
ec_hic = np.load('data/ec_adj_mat_t25.npy')
hsr_hic = np.load('data/hsr_adj_mat_t25.npy')

ec_hic = (ec_hic != 0).astype(int)
hsr_hic = (hsr_hic != 0).astype(int)

# %%
ec_df = pd.read_csv('data/ec_cleaned.csv', index_col=0)
hsr_df = pd.read_csv('data/hsr_cleaned.csv', index_col=0)

# %%
hsr_feats = torch.tensor(hsr_df[['read_count', 'total_genes']].to_numpy())
hsr_labels = torch.zeros(hsr_feats.shape[0])

ec_feats = torch.tensor(ec_df[['read_count', 'total_genes']].to_numpy())
ec_labels = torch.ones(ec_feats.shape[0])

# %%
def hic_to_sparse(hic_mat):
    #adj_mat = np.triu(hic_mat)
    sparse_adj = coo_matrix(hic_mat)

    return utils.from_scipy_sparse_matrix(sparse_adj)

# %%
hsr_edge_index, hsr_edge_attr = hic_to_sparse(hsr_hic)
hsr_graph = torch_geometric.data.Data(edge_index = hsr_edge_index, edge_attr = hsr_edge_attr, x = hsr_feats, y = hsr_labels)

ec_edge_index, ec_edge_attr = hic_to_sparse(ec_hic)
ec_graph = torch_geometric.data.Data(edge_index = ec_edge_index, edge_attr = ec_edge_attr, x = ec_feats, y = ec_labels)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
def train_one_epoch(node2vec, optimizer, loader):
    node2vec.train()
    total_loss = 0
    for pos_rw, neg_rw in loader:
        optimizer.zero_grad()
        loss = node2vec.loss(pos_rw.to(device), neg_rw.to(device))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def train_node2vec(G, n_epochs=100, verbose=True):
    node2vec = Node2Vec(edge_index=G.edge_index, embedding_dim=16, walk_length=3, context_size=2, walks_per_node=10, num_negative_samples=1, p = 1, q = 1, sparse=True)
    node2vec = node2vec.to(device)
    G = G.to(device)
    
    loader = node2vec.loader(batch_size=128, shuffle=True)
    #loader.edge_weight = G.edge_attr
    optimizer = torch.optim.SparseAdam(list(node2vec.parameters()), lr=0.01)

    for epoch in range(1, n_epochs+1):
        loss = train_one_epoch(node2vec, optimizer=optimizer, loader=loader)
        if verbose:
            print(f'Epoch: {epoch}, Loss: {loss:.4f}')

    node2vec.eval()
    return node2vec().detach().cpu()

# %%
ec_embeds = train_node2vec(ec_graph)
hsr_embeds = train_node2vec(hsr_graph)
# Out:
# Epoch: 1, Loss: 3.6129
# Epoch: 2, Loss: 3.5631
# Epoch: 3, Loss: 3.4223
# Epoch: 4, Loss: 3.4560
# Epoch: 5, Loss: 3.2426
# Epoch: 6, Loss: 3.3314
# Epoch: 7, Loss: 3.2213
# Epoch: 8, Loss: 3.0747
# Epoch: 9, Loss: 3.0687
# Epoch: 10, Loss: 2.9979
# Epoch: 11, Loss: 2.9731
# Epoch: 12, Loss: 2.8989
# Epoch: 13, Loss: 2.8120
# Epoch: 14, Loss: 2.7640
# Epoch: 15, Loss: 2.7684
# Epoch: 16, Loss: 2.7033
# Epoch: 17, Loss: 2.5844
# Epoch: 18, Loss: 2.5503
# Epoch: 19, Loss: 2.5483
# Epoch: 20, Loss: 2.4951
# Epoch: 21, Loss: 2.4374
# Epoch: 22, Loss: 2.3905
# Epoch: 23, Loss: 2.3780
# Epoch: 24, Loss: 2.3101
# Epoch: 25, Loss: 2.3177
# Epoch: 26, Loss: 2.2203
# Epoch: 27, Loss: 2.2487
# Epoch: 28, Loss: 2.2083
# Epoch: 29, Loss: 2.1574
# Epoch: 30, Loss: 2.1542
# Epoch: 31, Loss: 2.0356
# Epoch: 32, Loss: 2.0581
# Epoch: 33, Loss: 2.0373
# Epoch: 34, Loss: 2.0043
# Epoch: 35, Loss: 1.9952
# Epoch: 36, Loss: 1.9765
# Epoch: 37, Loss: 1.9679
# Epoch: 38, Loss: 1.9131
# ...

# %%
def log_normalize_tensor(tensor):
    tensor = tensor.float()
    tensor = torch.log1p(tensor)
    min_val, max_val = tensor.min(), tensor.max()
    return 2 * (tensor - min_val) / (max_val - min_val) - 1

# %%
normalized_ec_feats = ec_feats.clone()
normalized_ec_feats[:, 0] = log_normalize_tensor(ec_feats[:, 0])

normalized_hsr_feats = hsr_feats.clone()
normalized_hsr_feats[:, 0] = log_normalize_tensor(hsr_feats[:, 0])

# %%
ec_feats_and_embeds = torch.cat([ec_embeds, normalized_ec_feats], dim=1)
hsr_feats_and_embeds = torch.cat([hsr_embeds, normalized_hsr_feats], dim=1)

# %%
pca = PCA(n_components=2)
ec_pca_embeds = pca.fit_transform(ec_feats_and_embeds)
ec_pca_embeds.shape
# Out:
# (251, 2)

# %%
plt.figure(figsize=(10,10))
plt.scatter(ec_pca_embeds[:, 0], ec_pca_embeds[:, 1], color='red', label='ecDNA', alpha=0.7)
plt.title('EC PCA', fontsize=25)
plt.savefig('images/ecpca.png', pad_inches=0)
plt.show()

# %%
pca = PCA(n_components=2, random_state=seed)
hsr_pca_embeds = pca.fit_transform(hsr_feats_and_embeds)
hsr_pca_embeds.shape
# Out:
# (251, 2)

# %%
plt.figure(figsize=(10,10))
plt.scatter(hsr_pca_embeds[:, 0], hsr_pca_embeds[:, 1], color='blue', label='HSR', alpha=0.7)
plt.title('HSR PCA', fontsize=25)
plt.ylim(-2.5, 2.5)
plt.legend()
plt.savefig('images/hsrpca.png')
plt.show()

# %%
def db_cluster(embeds, eps=0.1, min_samples=5, save='ec'):
    X = embeds.copy()
    #X[:, 0] = np.log(X[:, 0] - np.min(X[:, 0]) + 1)
    
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    db_labels = dbscan.fit_predict(X) + 2
    
    plt.figure(figsize=(10, 10))
    unique_labels = set(db_labels)
    
    for label in unique_labels:
        color = plt.cm.viridis(label / len(unique_labels))
        label_name = f"Cluster {label}"
    
        plt.scatter(
            X[db_labels == label, 0], X[db_labels == label, 1],
            c=[color], label=label_name, edgecolors="k", alpha=0.7
        )
    
    plt.legend(fontsize=15)
    plt.title(f"DBSCAN (eps={eps}, min_samples={min_samples})", fontsize=25)
    if save:
        plt.savefig(f'images/{save}_clusters.png', pad_inches=0)
    plt.show()

    return db_labels

# %%
ec_db_labels = db_cluster(ec_pca_embeds, eps=0.15, min_samples=5, save='ec')

# %%
hsr_db_labels = db_cluster(hsr_pca_embeds, eps=0.15, min_samples=5, save='hsr')

# %%
def compute_node_properties(data):
    G = to_networkx(data, to_undirected=True)
    
    deg = degree(data.edge_index[0], num_nodes=data.num_nodes).numpy()
    
    clustering = nx.clustering(G)
    
    betweenness = nx.betweenness_centrality(G)
    
    pagerank = nx.pagerank(G)
    
    eigenvector = nx.eigenvector_centrality(G, max_iter=1000)

    df = pd.DataFrame({
        'node_id': list(range(data.num_nodes)),
        'degree': deg,
        'clustering': [clustering[i] for i in range(data.num_nodes)],
        'betweenness': [betweenness[i] for i in range(data.num_nodes)],
        'pagerank': [pagerank[i] for i in range(data.num_nodes)],
        'eigenvector': [eigenvector[i] for i in range(data.num_nodes)]
    })

    return df.set_index('node_id')

ec_prop_df = compute_node_properties(ec_graph.cpu())

# %%
ec_prop_df['DB_labels'] = ec_db_labels
ec_prop_df['pagerank_rank'] = ec_prop_df['pagerank'].rank(ascending=False, method='dense').astype(int)

ec_prop_df
# Out:
#          degree  clustering  betweenness  pagerank  eigenvector  DB_labels  \
# node_id
# 0          67.0    0.300317     0.003104  0.004215     0.063481          2
# 1          64.0    0.285714     0.003377  0.004085     0.058026          2
# 2          55.0    0.286869     0.002872  0.003628     0.048065          1
# 3          44.0    0.274841     0.001593  0.003013     0.039220          2
# 4          48.0    0.281028     0.002001  0.003243     0.041826          1
# ...         ...         ...          ...       ...          ...        ...
# 246        50.0    0.311020     0.001653  0.003282     0.049576          1
# 247        62.0    0.331042     0.002216  0.003905     0.063444          2
# 248        56.0    0.322078     0.002096  0.003608     0.055559          2
# 249        53.0    0.324383     0.001883  0.003453     0.052366          2
# 250        64.0    0.285714     0.002957  0.004060     0.060377          5
#
#          pagerank_rank
# node_id
# 0                   98
# ...

# %%
agg_ec_db = ec_prop_df.groupby('DB_labels').median()
agg_ec_db['count'] = ec_prop_df['DB_labels'].value_counts()

agg_ec_db
# Out:
#            degree  clustering  betweenness  pagerank  eigenvector  \
# DB_labels
# 1            55.0    0.301994     0.002302  0.003628     0.054215
# 2            64.0    0.294355     0.002806  0.004042     0.062354
# 3            78.0    0.288790     0.004610  0.004829     0.074940
# 4            65.0    0.306479     0.003075  0.004166     0.060812
# 5            60.0    0.285714     0.002745  0.003836     0.059113
#
#            pagerank_rank  count
# DB_labels
# 1                  159.0     67
# 2                  117.0    169
# 3                   45.0      5
# 4                  102.0      5
# 5                  138.0      5

# %%
hsr_prop_df = compute_node_properties(hsr_graph.cpu())
hsr_prop_df['pagerank_rank'] = hsr_prop_df['pagerank'].rank(ascending=False, method='dense').astype(int)
hsr_prop_df['DB_labels'] = hsr_db_labels

hsr_prop_df
# Out:
#          degree  clustering  betweenness  pagerank  eigenvector  \
# node_id
# 0          53.0    0.302612     0.001917  0.003458     0.051435
# 1          71.0    0.298592     0.003559  0.004433     0.067895
# 2          62.0    0.292438     0.002899  0.003962     0.057450
# 3          46.0    0.280193     0.001602  0.003099     0.041959
# 4          62.0    0.283977     0.002983  0.003969     0.057120
# ...         ...         ...          ...       ...          ...
# 246        53.0    0.293179     0.001929  0.003453     0.051355
# 247        57.0    0.274436     0.002387  0.003681     0.053842
# 248        50.0    0.315476     0.001539  0.003291     0.048661
# 249        59.0    0.265578     0.002529  0.003784     0.057230
# 250        43.0    0.274100     0.001336  0.002933     0.039694
#
#          pagerank_rank  DB_labels
# node_id
# 0                  186          2
# 1                   61          2
# 2                  112          2
# 3                  217          1
# ...

# %%
agg_hsr_db = hsr_prop_df.groupby('DB_labels').median()
agg_hsr_db['count'] = hsr_prop_df['DB_labels'].value_counts()

agg_hsr_db
# Out:
#            degree  clustering  betweenness  pagerank  eigenvector  \
# DB_labels
# 1            59.0    0.297458     0.002401  0.003760     0.058488
# 2            62.0    0.289966     0.002683  0.003951     0.060823
# 3            59.5    0.300148     0.002236  0.003806     0.058475
#
#            pagerank_rank  count
# DB_labels
# 1                  149.0     74
# 2                  114.0    171
# 3                  139.0      6

# %%
hsr_full_cluster_out = hsr_prop_df.merge(hsr_df.reset_index(drop=True), left_index=True, right_index=True)
ec_full_cluster_out = ec_prop_df.merge(ec_df.reset_index(drop=True), left_index=True, right_index=True)

ec_full_cluster_out.to_csv('outputs/ec_cluster_output.csv')
hsr_full_cluster_out.to_csv('outputs/hsr_cluster_output.csv')

# %%
ec_full_cluster_out[['degree', 'clustering', 'pagerank', 'read_count', 'total_genes', 'DB_labels']].head()
# Out:
#          degree  clustering  pagerank  read_count  total_genes  DB_labels
# node_id
# 0          67.0    0.300317  0.004215           7            0          2
# 1          64.0    0.285714  0.004085           4            0          2
# 2          55.0    0.286869  0.003628          20            0          1
# 3          44.0    0.274841  0.003013          20            0          2
# 4          48.0    0.281028  0.003243           7            0          1

# %%
df = ec_full_cluster_out.copy()

numerical_cols = ['degree', 'pagerank', 'read_count', 'total_genes']
db_labels = sorted(df['DB_labels'].unique())  # Ensure consistent order of labels

names = dict(zip(numerical_cols, ['Degree', 'Page Rank', 'Read Count', 'Gene Count']))

read_count_threshold = df['read_count'].quantile(0.95)
df['read_count_capped'] = df['read_count'].clip(upper=read_count_threshold)

n_rows = len(db_labels)
n_cols = len(numerical_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(25, 20), sharex='col', sharey='col')

for i, label in enumerate(db_labels):
    for j, col in enumerate(numerical_cols):
        col_to_plot = 'read_count_capped' if col == 'read_count' else col
        ax = axes[i, j] if n_rows > 1 else axes[j]

        bins = 20
        all_data = df[col_to_plot].dropna()
        bin_edges = np.linspace(all_data.min(), all_data.max(), bins + 1)

        subset = df[df['DB_labels'] == label][col_to_plot]

        counts, _ = np.histogram(subset, bins=bin_edges)
        proportions = counts / counts.sum() if counts.sum() > 0 else counts

        color = 'green' if col in ['read_count', 'total_genes'] else 'blue'
        ax.bar(bin_edges[:-1], proportions, width=np.diff(bin_edges), alpha=0.7, color=color, edgecolor='black')
        ax.set_ylim(0, 1)

        median_value = subset.median()
        ax.axvline(median_value, color='red', linestyle='dashed', linewidth=2, label='Median')

        mean_value = subset.mean()
        ax.axvline(mean_value, color='purple', linestyle='dashed', linewidth=2, label='Mean')

        if i == 0:
            ax.set_title(f"{names[col]}", fontsize=14)
        
        if j == 0:
            ax.set_ylabel(f"Cluster {label}", fontsize=14) 

fig.text(0.5, -0.02, "Red line = Median, Purple line = Mean", 
         ha='center', fontsize=14, color='black', fontweight='bold')

# Adjust layout
plt.tight_layout()
plt.savefig('images/ec_clustering_out.png')
plt.show()

# %%
ec_db_labels = sorted(df['DB_labels'].unique())
numerical_cols = ['degree', 'clustering', 'betweenness', 'pagerank', 'eigenvector']

ec_mann_whitney_results = {}

for col in numerical_cols:
    p_value_df = pd.DataFrame(index=ec_db_labels, columns=ec_db_labels, dtype=float)
    
    for cluster1, cluster2 in combinations(ec_db_labels, 2):
        group1 = df[df['DB_labels'] == cluster1][col].dropna()
        group2 = df[df['DB_labels'] == cluster2][col].dropna()
        
        stat, p_value = mannwhitneyu(group1, group2, alternative='two-sided')
        
        p_value_df.loc[cluster1, cluster2] = p_value
        p_value_df.loc[cluster2, cluster1] = p_value

    p_value_df.fillna(1, inplace=True)
    

    ec_mann_whitney_results[col] = p_value_df

ec_mann_whitney_results['pagerank']
# Out:
#           1         2         3         4         5
# 1  1.000000  0.016015  0.075949  0.248762  0.476249
# 2  0.016015  1.000000  0.179338  0.847628  0.868216
# 3  0.075949  0.179338  1.000000  0.222222  0.420635
# 4  0.248762  0.847628  0.222222  1.000000  0.547619
# 5  0.476249  0.868216  0.420635  0.547619  1.000000

# %%
# Set up the figure with one row of subplots
fig, axes = plt.subplots(1, len(numerical_cols), figsize=(20, 5), sharey=True)

# Create a single colorbar axis
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # Adjust position for colorbar

# Define color limits to keep scales consistent
vmin, vmax = 0, 1  # P-values range from 0 to 1

# Plot each heatmap
for ax, col in zip(axes, numerical_cols):
    sns.heatmap(
        ec_mann_whitney_results[col], 
        annot=True, 
        fmt=".3f", 
        cmap="coolwarm", 
        cbar=(ax == axes[-1]),  # Only add colorbar to last subplot
        vmin=vmin, 
        vmax=vmax, 
        ax=ax,
        cbar_ax=None if ax != axes[-1] else cbar_ax
    )
    ax.set_title(col, fontdict={'fontsize': 16})  # Set column name as title

# Adjust layout
plt.tight_layout(rect=[0, 0, 0.9, 1])  # Leave space for colorbar
plt.savefig('images/ec_pval_heatmap.png')
plt.show()
# Out:
# /tmp/ipykernel_601/3907650863.py:26: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])  # Leave space for colorbar

# %%
df = hsr_full_cluster_out.copy()
read_count_threshold = df['read_count'].quantile(0.95)
df['read_count_capped'] = df['read_count'].clip(upper=read_count_threshold)

hsr_db_labels = sorted(df['DB_labels'].unique())
numerical_cols = ['degree', 'clustering', 'betweenness', 'pagerank', 'eigenvector']

hsr_mann_whitney_results = {}

for col in numerical_cols:
    p_value_df = pd.DataFrame(index=hsr_db_labels, columns=hsr_db_labels, dtype=float)
    
    for cluster1, cluster2 in combinations(hsr_db_labels, 2):
        group1 = df[df['DB_labels'] == cluster1][col].dropna()
        group2 = df[df['DB_labels'] == cluster2][col].dropna()
        
        stat, p_value = mannwhitneyu(group1, group2, alternative='two-sided')
        
        p_value_df.loc[cluster1, cluster2] = p_value
        p_value_df.loc[cluster2, cluster1] = p_value

    p_value_df.fillna(1, inplace=True)
    

    hsr_mann_whitney_results[col] = p_value_df

hsr_mann_whitney_results['pagerank']
# Out:
#           1         2         3
# 1  1.000000  0.062287  0.809975
# 2  0.062287  1.000000  0.598469
# 3  0.809975  0.598469  1.000000

# %%
# Set up the figure with one row of subplots
fig, axes = plt.subplots(1, len(numerical_cols), figsize=(20, 5), sharey=True)

# Create a single colorbar axis
cbar_ax = fig.add_axes([0.92, 0.15, 0.02, 0.7])  # Adjust position for colorbar

# Define color limits to keep scales consistent
vmin, vmax = 0, 1  # P-values range from 0 to 1

# Plot each heatmap
for ax, col in zip(axes, numerical_cols):
    sns.heatmap(
        hsr_mann_whitney_results[col], 
        annot=True, 
        fmt=".3f", 
        cmap="coolwarm", 
        cbar=(ax == axes[-1]),  # Only add colorbar to last subplot
        vmin=vmin, 
        vmax=vmax, 
        ax=ax,
        cbar_ax=None if ax != axes[-1] else cbar_ax
    )
    ax.set_title(col, fontdict={'fontsize': 16})  # Set column name as title

# Adjust layout
plt.tight_layout(rect=[0, 0, 0.9, 1])  # Leave space for colorbar
plt.savefig('images/hsr_pval_heatmap.png')
plt.show()

# %%
genes = pd.read_csv('chrom7_genes.csv')
start_loci = 54765000
end_loci = 56050000
genes = genes[((genes['start'] >= start_loci) & (genes['start'] < end_loci)) | 
                       ((genes['end'] >= start_loci) & (genes['end'] < end_loci))]
genes['gene'] = genes['attributes'].str.split(';').str[0].str.split('ID=gene-').str[-1]
genes = genes[['gene', 'start', 'end']]
genes = genes[genes['gene'] != 'LOC101060341']
genes
# Out:
#              gene     start       end
# 679     SEC61G-DT  54759313  54804969
# 680  LOC124901636  54806443  54812133
# 681  LOC105375284  54992419  55018922
# 682          EGFR  55019017  55211628
# 683      EGFR-AS1  55179750  55188949
# 684          ELDR  55238436  55255635
# 685        LANCL2  55365337  55433737
# 686         VOPP1  55434964  55572502
# 687      VOPP1-DT  55572766  55596660
# 689  LOC102723656  55750747  55758860
# 690      SEPTIN14  55793540  55862752
# 691        ZNF713  55887456  55942225
# 692        MRPS17  55951877  55956500
# 693      NIPSNAP2  55964585  56000179
# 694          PSPH  56011064  56051444

# %%
db_labels = ec_prop_df['DB_labels'].values

cluster_indices = {}
for i in np.unique(db_labels):
    y_coords = np.array(ec_prop_df[ec_prop_df['DB_labels'] == i].index)

    cluster_indices[i] = y_coords

cluster_indices
# Out:
# {1: array([  2,   4,   5,   6,   7,  13,  15,  19,  28,  33,  45,  48,  49,
#          51,  52,  65,  68,  69,  70,  71,  72,  74,  75,  76,  80,  81,
#          84,  89,  90,  91,  97,  98, 100, 104, 111, 114, 123, 124, 127,
#         130, 135, 136, 140, 144, 152, 156, 158, 163, 167, 169, 174, 176,
#         179, 184, 188, 189, 194, 205, 208, 210, 212, 229, 233, 239, 244,
#         245, 246]),
#  2: array([  0,   1,   3,   8,   9,  10,  11,  14,  16,  17,  18,  20,  21,
#          22,  23,  24,  25,  26,  27,  29,  30,  31,  35,  36,  37,  38,
#          40,  41,  42,  43,  46,  47,  50,  53,  54,  55,  56,  57,  58,
#          59,  60,  61,  63,  64,  66,  67,  73,  77,  78,  79,  83,  85,
#          86,  87,  88,  92,  94,  95,  96,  99, 101, 102, 103, 105, 106,
#         107, 108, 109, 110, 112, 113, 115, 116, 117, 118, 119, 120, 121,
#         122, 125, 126, 128, 129, 131, 132, 133, 134, 137, 138, 139, 141,
# ...

# %%
fig, axes = plt.subplots(nrows=3, figsize=(12, 10), gridspec_kw={'height_ratios': [0.1, 10, 0.8]})

ax1 = axes[1]
sns.heatmap(np.log(ec_full_hic), cbar=False, xticklabels=False, yticklabels=False, 
            cmap=sns.color_palette("YlOrBr", as_cmap=True), ax=ax1)

pos = dict(zip(np.unique(db_labels), [28, 56, 82, 143, 220]))
color = dict(zip(np.unique(db_labels), ['green', 'lime', 'black', 'blue', 'magenta']))

for k, v in cluster_indices.items():
    y_coords = v
    x_coords = pos[k] + np.ones_like(y_coords)
    ax1.scatter(y_coords, x_coords, color=color[k], marker='o', s=50, label=f"Cluster {k}", facecolors='none')
ax1.legend()

# Gene track
ax3 = axes[2]
ax3.set_xlim(start_loci, end_loci)
ax3.set_ylim(-1, len(genes))
ax3.set_yticks([])
ax3.set_xlabel("")

ax3.set_xticks([])

for spine in ax3.spines.values():
    spine.set_visible(False)

genes["row"] = range(len(genes))

for _, row in genes.iterrows():
    gene_start, gene_end, gene_name, row_idx = row['start'], row['end'], row['gene'], row['row']
    width = gene_end - gene_start
    y_pos = row_idx * 0.5

    rect = mpatches.Rectangle((gene_start, y_pos), width, 0.3, edgecolor='black', facecolor='blue', alpha=0.7, label="_nolegend_")
    ax3.add_patch(rect)

    ax3.text((gene_start + gene_end) / 2, y_pos - 0.4, gene_name,
              fontsize=10, ha='center', va='top', rotation=90, fontweight='bold')

# Genomic position axis
ax2 = axes[0]
ax2.set_xlim(start_loci, end_loci)
ax2.set_ylim(0, 1)
ax2.set_yticks([])
ax2.set_xlabel("Genomic Position (bp x 1e7)", labelpad=-35, fontsize=13)

for spine in ax2.spines.values():
    spine.set_visible(False)
ax2.spines['bottom'].set_visible(True)

plt.subplots_adjust(hspace=0.2)
plt.savefig('images/ec_hic_clusters.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
db_labels = hsr_prop_df['DB_labels'].values

cluster_indices = {}
for i in np.unique(db_labels):
    y_coords = np.array(hsr_prop_df[hsr_prop_df['DB_labels'] == i].index)

    cluster_indices[i] = y_coords

cluster_indices
# Out:
# {1: array([  3,   6,   9,  11,  13,  17,  20,  24,  29,  30,  31,  32,  38,
#          39,  47,  48,  57,  58,  60,  62,  63,  67,  76,  78,  87,  92,
#          95,  96,  98, 101, 108, 109, 111, 119, 125, 126, 127, 128, 133,
#         134, 140, 141, 144, 145, 148, 150, 151, 153, 159, 161, 163, 169,
#         170, 173, 175, 177, 178, 185, 186, 189, 195, 196, 202, 203, 205,
#         207, 211, 229, 235, 236, 238, 243, 246, 248]),
#  2: array([  0,   1,   2,   4,   5,   7,   8,  10,  12,  14,  15,  16,  18,
#          19,  21,  22,  23,  25,  26,  27,  28,  33,  34,  35,  36,  37,
#          40,  41,  42,  43,  44,  45,  46,  49,  50,  51,  52,  53,  54,
#          55,  56,  59,  61,  64,  65,  66,  68,  69,  70,  71,  72,  73,
#          74,  75,  77,  79,  80,  81,  82,  83,  84,  85,  86,  88,  89,
#          90,  91,  94,  97,  99, 100, 102, 103, 104, 105, 106, 107, 110,
#         112, 113, 114, 115, 116, 117, 118, 121, 122, 123, 124, 129, 130,
# ...

# %%
fig, axes = plt.subplots(nrows=3, figsize=(12, 10), gridspec_kw={'height_ratios': [0.1, 10, 0.8]})

ax1 = axes[1]
hsr_full_hic[hsr_full_hic == 0] = np.mean(hsr_full_hic)
sns.heatmap(np.log(hsr_full_hic, where=hsr_full_hic!=0), cbar=False, xticklabels=False, yticklabels=False, 
            cmap=sns.color_palette("YlOrBr", as_cmap=True), ax=ax1)

pos = dict(zip(np.unique(db_labels), [76, 152, 216, 143, 220]))
color = dict(zip(np.unique(db_labels), ['green', 'magenta', 'black', 'blue', 'lime']))

for k, v in cluster_indices.items():
    y_coords = v
    x_coords = pos[k] + np.ones_like(y_coords)
    ax1.scatter(y_coords, x_coords, color=color[k], marker='o', s=50, label=f"Cluster {k}", facecolors='none')
ax1.legend()

# Gene track
ax3 = axes[2]
ax3.set_xlim(start_loci, end_loci)
ax3.set_ylim(-1, len(genes))
ax3.set_yticks([])
ax3.set_xlabel("")

ax3.set_xticks([])

for spine in ax3.spines.values():
    spine.set_visible(False)

genes["row"] = range(len(genes))

for _, row in genes.iterrows():
    gene_start, gene_end, gene_name, row_idx = row['start'], row['end'], row['gene'], row['row']
    width = gene_end - gene_start
    y_pos = row_idx * 0.5

    rect = mpatches.Rectangle((gene_start, y_pos), width, 0.3, edgecolor='black', facecolor='blue', alpha=0.7, label="_nolegend_")
    ax3.add_patch(rect)

    ax3.text((gene_start + gene_end) / 2, y_pos - 0.4, gene_name,
              fontsize=10, ha='center', va='top', rotation=90, fontweight='bold')

# Genomic position axis
ax2 = axes[0]
ax2.set_xlim(start_loci, end_loci)
ax2.set_ylim(0, 1)
ax2.set_yticks([])
ax2.set_xlabel("Genomic Position (bp x 1e7)", labelpad=-35, fontsize=13)

for spine in ax2.spines.values():
    spine.set_visible(False)
ax2.spines['bottom'].set_visible(True)

plt.subplots_adjust(hspace=0.2)
plt.savefig('images/hsr_hic_clusters.png', dpi=300, bbox_inches='tight')
plt.show()
