# %%
import pandas as pd
import numpy as np

# %%
pd.read_table('counts.txt')
# Out:
#                                                                                                                                                                                                   # Program:featureCounts v2.0.8; Command:"featureCounts" "-a" "genomic.gff" "-o" "counts.txt" "-g" "gene" "aligned.bam"
# Geneid      Chr                                                Start                                              End                                                Strand                Length                                        aligned.bam
# DDX11L1     NC_000001.11;NC_000001.11;NC_000001.11             11874;12613;13221                                  12227;12721;14409                                  +;+;+                 1652                                                    0
# ...
