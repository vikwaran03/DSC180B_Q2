# %%
import torch
import random
import torch_geometric
from torch_geometric import utils
from scipy.sparse import coo_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import rbf_kernel

from torch_geometric.utils import degree, to_networkx
from torch_geometric.nn.models import Node2Vec

import networkx as nx

# %%
seed = 0

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
ec_hic = np.load('data/GBM39ec_5k_collapsed_matrix.npy')
hsr_hic = np.load('data/GBM39HSR_5k_collapsed_matrix.npy')

# %%
ec_hic = np.load('data/ec_adj_mat.npy')
hsr_hic = np.load('data/hsr_adj_mat.npy')

ec_hic = (ec_hic != 0).astype(int)
hsr_hic = (hsr_hic != 0).astype(int)

# %%
ec_df = pd.read_csv('data/ec_cleaned.csv', index_col=0)
hsr_df = pd.read_csv('data/hsr_cleaned.csv', index_col=0)

# %%
hsr_feats = torch.tensor(hsr_df[['read_count', 'total_genes']].to_numpy())
hsr_labels = torch.zeros(hsr_feats.shape[0])

ec_feats = torch.tensor(ec_df[['read_count', 'total_genes']].to_numpy())
ec_labels = torch.ones(ec_feats.shape[0])

# %%
def hic_to_sparse(hic_mat):
    #adj_mat = np.triu(hic_mat)
    sparse_adj = coo_matrix(hic_mat)

    return utils.from_scipy_sparse_matrix(sparse_adj)

# %%
hsr_edge_index, hsr_edge_attr = hic_to_sparse(hsr_hic)
hsr_graph = torch_geometric.data.Data(edge_index = hsr_edge_index, edge_attr = hsr_edge_attr, x = hsr_feats, y = hsr_labels)

ec_edge_index, ec_edge_attr = hic_to_sparse(ec_hic)
ec_graph = torch_geometric.data.Data(edge_index = ec_edge_index, edge_attr = ec_edge_attr, x = ec_feats, y = ec_labels)

# %%
x = torch.cat([ec_feats, hsr_feats], dim=0)
hsr_edge_index = hsr_edge_index + ec_labels.shape[0]
edge_index = torch.cat([ec_edge_index, hsr_edge_index], dim=1)
edge_attr = torch.cat([ec_edge_attr, hsr_edge_attr], dim=0)
edge_index, edge_attr = utils.to_undirected(edge_index, edge_attr)
labels = torch.cat([ec_labels, hsr_labels], dim=0)

G = torch_geometric.data.Data(edge_index = edge_index, edge_attr = edge_attr, x = x, y = labels)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
def train_one_epoch(node2vec, optimizer, loader):
    node2vec.train()
    total_loss = 0
    for pos_rw, neg_rw in loader:
        optimizer.zero_grad()
        loss = node2vec.loss(pos_rw.to(device), neg_rw.to(device))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

def train_node2vec(G, n_epochs=100, verbose=True):
    node2vec = Node2Vec(edge_index=G.edge_index, embedding_dim=16, walk_length=3, context_size=2, walks_per_node=10, num_negative_samples=1, p = 1, q = 1, sparse=True)
    node2vec = node2vec.to(device)
    G = G.to(device)
    
    loader = node2vec.loader(batch_size=128, shuffle=True)
    #loader.edge_weight = G.edge_attr
    optimizer = torch.optim.SparseAdam(list(node2vec.parameters()), lr=0.01)

    for epoch in range(1, n_epochs+1):
        loss = train_one_epoch(node2vec, optimizer=optimizer, loader=loader)
        if verbose:
            print(f'Epoch: {epoch}, Loss: {loss:.4f}')

    node2vec.eval()
    return node2vec().detach().cpu()

# %%
embeds = train_node2vec(G, n_epochs=200)
# Epoch: 155, Loss: 1.1084
# Epoch: 156, Loss: 1.1288
# Epoch: 157, Loss: 1.1212
# Epoch: 158, Loss: 1.1109
# Epoch: 159, Loss: 1.1158
# Epoch: 160, Loss: 1.1122
# Epoch: 161, Loss: 1.1123
# Epoch: 162, Loss: 1.1180
# Epoch: 163, Loss: 1.1124
# Epoch: 164, Loss: 1.1116
# Epoch: 165, Loss: 1.1271
# Epoch: 166, Loss: 1.1157
# Epoch: 167, Loss: 1.1129
# Epoch: 168, Loss: 1.1244
# Epoch: 169, Loss: 1.1111
# Epoch: 170, Loss: 1.1168
# Epoch: 171, Loss: 1.1162
# Epoch: 172, Loss: 1.1090
# Epoch: 173, Loss: 1.1156
# Epoch: 174, Loss: 1.1125
# Epoch: 175, Loss: 1.1138
# Epoch: 176, Loss: 1.1121
# Epoch: 177, Loss: 1.1071
# Epoch: 178, Loss: 1.1109
# Epoch: 179, Loss: 1.1203
# Epoch: 180, Loss: 1.1174
# Epoch: 181, Loss: 1.1053
# Epoch: 182, Loss: 1.1185
# Epoch: 183, Loss: 1.1182
# Epoch: 184, Loss: 1.1135
# Epoch: 185, Loss: 1.1122
# Epoch: 186, Loss: 1.1116
# Epoch: 187, Loss: 1.1071
# Epoch: 188, Loss: 1.1123
# Epoch: 189, Loss: 1.1137
# Epoch: 190, Loss: 1.1100
# Epoch: 191, Loss: 1.1118
# Epoch: 192, Loss: 1.1036
# Epoch: 193, Loss: 1.1193
# Epoch: 194, Loss: 1.0994
# Epoch: 195, Loss: 1.1121
# Epoch: 196, Loss: 1.1066
# Epoch: 197, Loss: 1.1121
# Epoch: 198, Loss: 1.1037
# Epoch: 199, Loss: 1.1203
# Epoch: 200, Loss: 1.1071

# %%
feats_and_embeds = torch.cat([embeds, x], dim=1)

# %%
X = feats_and_embeds.numpy()
y = G.y.cpu().numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
mdl = LogisticRegression(solver='liblinear')
mdl.fit(X_train, y_train)

preds = mdl.predict(X_test)
print(f'Logistic Regression Accuracy (1 Graph): {(preds == y_test).mean()}')
# Out:
# Logistic Regression Accuracy (1 Graph): 1.0

# %%
embeds = feats_and_embeds
pca = PCA(n_components=2, random_state=seed)
pca_embeds = pca.fit_transform(embeds)
pca_embeds.shape
# Out:
# (502, 2)

# %%
ec_mask = (G.y == 1).cpu()

plt.figure(figsize=(10,10))
plt.scatter(pca_embeds[:, 0][ec_mask], pca_embeds[:, 1][ec_mask], color='red', label='ecDNA', alpha=0.7)
plt.scatter(pca_embeds[:, 0][~ec_mask], pca_embeds[:, 1][~ec_mask], color='blue', label='HSR', alpha=0.7)
plt.legend()
plt.show()

# %%
ec_embeds = train_node2vec(ec_graph)
hsr_embeds = train_node2vec(hsr_graph)
# Out:
# Epoch: 1, Loss: 3.4345
# Epoch: 2, Loss: 3.5217
# Epoch: 3, Loss: 3.3317
# Epoch: 4, Loss: 3.3072
# Epoch: 5, Loss: 3.2947
# Epoch: 60, Loss: 1.6656
# Epoch: 61, Loss: 1.6533
# Epoch: 62, Loss: 1.6548
# Epoch: 63, Loss: 1.6178
# Epoch: 64, Loss: 1.6197
# Epoch: 65, Loss: 1.6431
# Epoch: 66, Loss: 1.6273
# Epoch: 67, Loss: 1.6282
# Epoch: 68, Loss: 1.6010
# Epoch: 69, Loss: 1.5931
# Epoch: 70, Loss: 1.5604
# Epoch: 71, Loss: 1.5716
# Epoch: 72, Loss: 1.5679
# Epoch: 73, Loss: 1.5528
# Epoch: 74, Loss: 1.5588
# Epoch: 75, Loss: 1.5359
# Epoch: 76, Loss: 1.5341
# Epoch: 77, Loss: 1.5588
# Epoch: 78, Loss: 1.5465
# Epoch: 79, Loss: 1.5340
# Epoch: 80, Loss: 1.5337
# Epoch: 81, Loss: 1.5320
# Epoch: 82, Loss: 1.5231
# Epoch: 83, Loss: 1.5230
# Epoch: 84, Loss: 1.5252
# Epoch: 85, Loss: 1.5064
# Epoch: 86, Loss: 1.4805
# Epoch: 87, Loss: 1.4876
# Epoch: 88, Loss: 1.4901
# Epoch: 89, Loss: 1.4856
# Epoch: 90, Loss: 1.4847
# Epoch: 91, Loss: 1.4823
# Epoch: 92, Loss: 1.4855
# Epoch: 93, Loss: 1.4598
# Epoch: 94, Loss: 1.4711
# Epoch: 95, Loss: 1.4650
# Epoch: 96, Loss: 1.4708
# Epoch: 97, Loss: 1.4595
# Epoch: 98, Loss: 1.4647
# Epoch: 99, Loss: 1.4509
# Epoch: 100, Loss: 1.4544

# %%
ec_feats_and_embeds = torch.cat([ec_embeds, ec_feats], dim=1)
hsr_feats_and_embeds = torch.cat([hsr_embeds, hsr_feats], dim=1)

# %%
pca = PCA(n_components=2)
ec_pca_embeds = pca.fit_transform(ec_feats_and_embeds)
ec_pca_embeds.shape
# Out:
# (251, 2)

# %%
plt.figure(figsize=(10,10))
plt.scatter(ec_pca_embeds[:, 0], ec_pca_embeds[:, 1], color='red', label='ecDNA', alpha=0.7)
plt.title('EC PCA')
plt.legend()
plt.show()

# %%
pca = PCA(n_components=2, random_state=seed)
hsr_pca_embeds = pca.fit_transform(hsr_feats_and_embeds)
hsr_pca_embeds.shape
# Out:
# (251, 2)

# %%
plt.figure(figsize=(10,10))
plt.scatter(hsr_pca_embeds[:, 0], hsr_pca_embeds[:, 1], color='blue', label='HSR', alpha=0.7)
plt.title('HSR PCA')
plt.ylim(-2.5, 2.5)
plt.legend()
plt.show()

# %%
X = ec_pca_embeds.copy()
X[:, 0] = np.log(X[:, 0] - np.min(X[:, 0]) + 1)

plt.figure(figsize=(10,10))
plt.scatter(X[:, 0], X[:, 1], color='red', label='ecDNA', alpha=0.7)
plt.title('EC PCA (Log Transform X-axis)')
plt.legend()
plt.show()

# %%
def km_cluster(embeds, k=4):
    X = embeds.copy()
    X[:, 0] = np.log(X[:, 0] - np.min(X[:, 0]) + 1)

    gamma = 1 / (2 * np.var(X))
    K_rbf = rbf_kernel(X, gamma=gamma)
    
    n_clusters = k
    kmeans = KMeans(n_clusters=n_clusters, random_state=42)
    km_labels = kmeans.fit_predict(K_rbf)
    
    plt.figure(figsize=(8, 6))
    unique_labels = set(km_labels)
    
    for label in unique_labels:
        color = plt.cm.viridis(label / len(unique_labels))
        label_name = f"Cluster {label}"
    
        plt.scatter(
            X[km_labels == label, 0], X[km_labels == label, 1],
            c=[color], label=label_name, edgecolors="k", alpha=0.7
        )
    
    
    plt.legend()
    plt.title(f"KMeans Clustering with RBF Kernel")
    plt.show()

    return km_labels

# %%
def db_cluster(embeds, eps=0.1, min_samples=5):
    X = embeds.copy()
    X[:, 0] = np.log(X[:, 0] - np.min(X[:, 0]) + 1)
    
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    db_labels = dbscan.fit_predict(X)
    
    plt.figure(figsize=(8, 6))
    unique_labels = set(db_labels)
    
    for label in unique_labels:
        if label == -1:
            color = "red" 
            label_name = "Outliers"
        else:
            color = plt.cm.viridis(label / len(unique_labels))
            label_name = f"Cluster {label}"
    
        plt.scatter(
            X[db_labels == label, 0], X[db_labels == label, 1],
            c=[color], label=label_name, edgecolors="k", alpha=0.7
        )
    
    plt.legend()
    plt.title(f"DBSCAN (eps={eps}, min_samples={min_samples})")
    plt.show()

    return db_labels

# %%
ec_km_labels = km_cluster(ec_pca_embeds, k=8)

# %%
ec_db_labels = db_cluster(ec_pca_embeds, eps=0.4, min_samples=5)

# %%
hsr_km_labels = km_cluster(hsr_pca_embeds)

# %%
hsr_db_labels = db_cluster(hsr_pca_embeds, eps=0.4, min_samples=5)

# %%
def compute_node_properties(data):
    G = to_networkx(data, to_undirected=True)
    
    deg = degree(data.edge_index[0], num_nodes=data.num_nodes).numpy()
    
    clustering = nx.clustering(G)
    
    betweenness = nx.betweenness_centrality(G)
    
    pagerank = nx.pagerank(G)
    
    eigenvector = nx.eigenvector_centrality(G, max_iter=1000)

    df = pd.DataFrame({
        'node_id': list(range(data.num_nodes)),
        'degree': deg,
        'clustering': [clustering[i] for i in range(data.num_nodes)],
        'betweenness': [betweenness[i] for i in range(data.num_nodes)],
        'pagerank': [pagerank[i] for i in range(data.num_nodes)],
        'eigenvector': [eigenvector[i] for i in range(data.num_nodes)]
    })

    return df.set_index('node_id')

ec_prop_df = compute_node_properties(ec_graph.cpu())

# %%
ec_prop_df['DB_labels'] = ec_db_labels
ec_prop_df['KM_labels'] = ec_km_labels
ec_prop_df['pagerank_rank'] = ec_prop_df['pagerank'].rank(ascending=False, method='dense').astype(int)

ec_prop_df
# Out:
#          degree  clustering  betweenness  pagerank  eigenvector  DB_labels  \
# node_id
# 0         135.0    0.535766     0.002236  0.004239     0.066927          0
# 1         132.0    0.500925     0.002485  0.004176     0.063439          0
# 2         127.0    0.505687     0.002262  0.004041     0.061171          0
# 3          93.0    0.514259     0.001181  0.003120     0.044857         -1
# 4          99.0    0.507524     0.001454  0.003300     0.045958          0
# ...         ...         ...          ...       ...          ...        ...
# 246       118.0    0.554542     0.001564  0.003768     0.060111          0
# 247       127.0    0.568804     0.001672  0.004002     0.065268          2
# 248       126.0    0.555429     0.001785  0.003983     0.064128          0
# 249       114.0    0.542351     0.001525  0.003670     0.056826          0
# 250       122.0    0.540220     0.001751  0.003885     0.060889          0
#
#          KM_labels  pagerank_rank
# node_id
# 0                0             90
# 1                5            101
# 2                0            128
# 3                0            234
# 4                0            223
# ...            ...            ...
# 246              7            165
# 247              7            135
# 248              3            139
# 249              4            175
# 250              3            152
#
# [251 rows x 8 columns]

# %%
agg_ec_db = ec_prop_df.drop(columns=['KM_labels']).groupby('DB_labels').median()
agg_ec_db['count'] = ec_prop_df['DB_labels'].value_counts()

agg_ec_db
# Out:
#            degree  clustering  betweenness  pagerank  eigenvector  \
# DB_labels
# -1          112.0    0.533040     0.001462  0.003610     0.056463
#  0          128.0    0.531366     0.002041  0.004065     0.064128
#  1          118.0    0.532616     0.001755  0.003787     0.059084
#  2          140.5    0.535490     0.002456  0.004387     0.069847
#
#            pagerank_rank  count
# DB_labels
# -1                 183.0     28
#  0                 122.0    185
#  1                 161.0     32
#  2                  64.5      6

# %%
agg_ec_km = ec_prop_df.drop(columns=['DB_labels']).groupby('KM_labels').median()
agg_ec_km['count'] = ec_prop_df['KM_labels'].value_counts()

agg_ec_km
# Out:
#            degree  clustering  betweenness  pagerank  eigenvector  \
# KM_labels
# 0           131.0    0.530599     0.002053  0.004119     0.065913
# 1           128.5    0.535335     0.002035  0.004063     0.064221
# 2           118.0    0.533744     0.001731  0.003781     0.059808
# 3           119.0    0.538717     0.001751  0.003800     0.059881
# 4           132.0    0.526406     0.002189  0.004143     0.064245
# 5           132.5    0.526024     0.002161  0.004177     0.065153
# 6           115.0    0.530836     0.001755  0.003709     0.056499
# 7           130.0    0.534147     0.002043  0.004108     0.065268
#
#            pagerank_rank  count
# KM_labels
# 0                  112.0     59
# 1                  122.5     26
# 2                  162.0     26
# 3                  160.0     37
# 4                  107.0     49
# 5                  100.5     22
# 6                  171.0     13
# 7                  113.0     19

# %%
hsr_prop_df = compute_node_properties(hsr_graph.cpu())
hsr_prop_df['pagerank_rank'] = hsr_prop_df['pagerank'].rank(ascending=False, method='dense').astype(int)
hsr_prop_df['DB_labels'] = hsr_db_labels
hsr_prop_df['KM_labels'] = hsr_km_labels

hsr_prop_df
# Out:
#          degree  clustering  betweenness  pagerank  eigenvector  \
# node_id
# 0         129.0    0.521777     0.002046  0.004078     0.064257
# 1         131.0    0.524839     0.002173  0.004136     0.064676
# 2         120.0    0.502241     0.001982  0.003850     0.057909
# 3         107.0    0.507318     0.001540  0.003495     0.051941
# 4         113.0    0.506005     0.001710  0.003657     0.054990
# ...         ...         ...          ...       ...          ...
# 246       125.0    0.511871     0.002009  0.003971     0.062028
# 247       130.0    0.531544     0.002022  0.004099     0.065277
# 248       126.0    0.514065     0.002012  0.004000     0.062351
# 249       107.0    0.521294     0.001384  0.003483     0.053331
# 250       104.0    0.524653     0.001303  0.003405     0.051577
#
#          pagerank_rank  DB_labels  KM_labels
# node_id
# 0                  102          0          2
# 1                   93         -1          1
# 2                  149          0          2
# 3                  216         -1          1
# 4                  187          0          1
# ...                ...        ...        ...
# 246                120          0          1
# 247                 97          2          3
# 248                115          0          2
# 249                218          0          1
# 250                226         -1          2
#
# [251 rows x 8 columns]

# %%
agg_hsr_db = hsr_prop_df.drop(columns=['KM_labels']).groupby('DB_labels').median()
agg_hsr_db['count'] = hsr_prop_df['DB_labels'].value_counts()

agg_hsr_db
# Out:
#            degree  clustering  betweenness  pagerank  eigenvector  \
# DB_labels
# -1          120.0    0.521578     0.001775  0.003842     0.059745
#  0          125.0    0.521562     0.001975  0.003970     0.062375
#  1          121.0    0.521892     0.001956  0.003865     0.059988
#  2          126.5    0.527157     0.001962  0.004011     0.063223
#  3          127.0    0.537269     0.001920  0.004019     0.063884
#
#            pagerank_rank  count
# DB_labels
# -1                 152.0     39
#  0                 121.5    178
#  1                 144.0     11
#  2                 113.0     16
#  3                 114.0      7

# %%
agg_hsr_km = hsr_prop_df.drop(columns=['DB_labels']).groupby('KM_labels').median()
agg_hsr_km['count'] = hsr_prop_df['KM_labels'].value_counts()

agg_hsr_km
# Out:
#            degree  clustering  betweenness  pagerank  eigenvector  \
# KM_labels
# 0           123.0    0.529138     0.001769  0.003911     0.061535
# 1           124.0    0.522437     0.001885  0.003939     0.062028
# 2           131.0    0.516571     0.002232  0.004144     0.064257
# 3           120.5    0.524910     0.001792  0.003848     0.060008
#
#            pagerank_rank  count
# KM_labels
# 0                  133.0     65
# 1                  128.0     79
# 2                   91.0     57
# 3                  149.5     50

# %%
plt.figure(figsize=(10,10))

for cluster in ec_prop_df.DB_labels.unique():
    if cluster == -1:
        color = "red"
    else:
        color = plt.cm.viridis(cluster / ec_prop_df.DB_labels.nunique())
        
    plt.scatter(ec_pca_embeds[:, 0][ec_prop_df.DB_labels == cluster], ec_pca_embeds[:, 1][ec_prop_df.DB_labels == cluster], alpha=0.7, label=f'Cluster {cluster}', c=[color])

plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(hsr_pca_embeds[:, 0], hsr_pca_embeds[:, 1], color='blue', label='HSR', alpha=0.7)
plt.title('HSR PCA')
plt.ylim(-2.5, 2.5)
plt.legend()
plt.show()

# %%
hsr_embeds2 = train_node2vec(hsr_graph, verbose=False)
hsr_feats_and_embeds = torch.cat([hsr_embeds2, hsr_feats], dim=1)
pca = PCA(n_components=2, random_state=seed)
hsr_pca_embeds2 = pca.fit_transform(hsr_feats_and_embeds)

plt.figure(figsize=(10,10))
plt.scatter(hsr_pca_embeds2[:, 0], hsr_pca_embeds2[:, 1], color='blue', label='HSR', alpha=0.7)
plt.title('HSR PCA')
plt.ylim(-2.5, 2.5)
plt.legend()
plt.show()

# %%
hsr_full_cluster_out = hsr_prop_df.merge(hsr_df.reset_index(drop=True), left_index=True, right_index=True)
ec_full_cluster_out = ec_prop_df.merge(ec_df.reset_index(drop=True), left_index=True, right_index=True)

ec_full_cluster_out.to_csv('outputs/ec_cluster_output.csv')
hsr_full_cluster_out.to_csv('outputs/hsr_cluster_output.csv')

# %%
ec_full_cluster_out[['degree', 'clustering', 'pagerank', 'read_count', 'total_genes', 'DB_labels']].head()
# Out:
#          degree  clustering  pagerank  read_count  total_genes  DB_labels
# node_id
# 0         135.0    0.535766  0.004239           7            0          0
# 1         132.0    0.500925  0.004176           4            0          0
# 2         127.0    0.505687  0.004041          20            0          0
# 3          93.0    0.514259  0.003120          20            0         -1
# 4          99.0    0.507524  0.003300           7            0          0

# %%
df = ec_full_cluster_out.copy()

numerical_cols = ['degree', 'clustering', 'pagerank', 'read_count', 'total_genes']
db_labels = sorted(df['DB_labels'].unique())  # Ensure consistent order of labels

read_count_threshold = df['read_count'].quantile(0.95)
df['read_count_capped'] = df['read_count'].clip(upper=read_count_threshold)

n_rows = len(db_labels)
n_cols = len(numerical_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(25, 20), sharex='col', sharey='col')

for i, label in enumerate(db_labels):
    for j, col in enumerate(numerical_cols):
        col_to_plot = 'read_count_capped' if col == 'read_count' else col
        ax = axes[i, j] if n_rows > 1 else axes[j]

        bins = 20
        all_data = df[col_to_plot].dropna()
        bin_edges = np.linspace(all_data.min(), all_data.max(), bins + 1)

        subset = df[df['DB_labels'] == label][col_to_plot]

        counts, _ = np.histogram(subset, bins=bin_edges)
        proportions = counts / counts.sum() if counts.sum() > 0 else counts

        color = 'green' if col in ['read_count', 'total_genes'] else 'blue'
        ax.bar(bin_edges[:-1], proportions, width=np.diff(bin_edges), alpha=0.7, color=color, edgecolor='black')
        ax.set_ylim(0, 1)

        median_value = subset.median()
        ax.axvline(median_value, color='red', linestyle='dashed', linewidth=2, label='Median')

        mean_value = subset.mean()
        ax.axvline(mean_value, color='purple', linestyle='dashed', linewidth=2, label='Mean')

        if i == 0:
            ax.set_title(f"{names[col]}", fontsize=14)
        
        if j == 0:
            ax.set_ylabel(f"Cluster {label}", fontsize=14) 

fig.text(0.5, -0.02, "Red line = Median, Purple line = Mean", 
         ha='center', fontsize=14, color='black', fontweight='bold')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

fig, axes = plt.subplots(n_rows, n_cols, figsize=(25, 20), sharex='col', sharey='row')

for i, label in enumerate(db_labels):
    for j, col in enumerate(numerical_cols):
        col_to_plot = 'read_count_capped' if col == 'read_count' else col
        ax = axes[i, j] if n_rows > 1 else axes[j]

        subset = df[df['DB_labels'] == label][col_to_plot]

        color = '#90EE90' if col in ['read_count', 'total_genes'] else '#ADD8E6'
        sns.boxplot(x=subset, ax=ax, color=color)

        ax.set_xlabel("")
        ax.tick_params(axis='x', which='both', labelbottom=True)
        
        if i == 0:
            ax.set_title(f"{names[col]}", fontsize=14)

        if j == 0:
            ax.set_ylabel(f"Cluster {label}", fontsize=14)

plt.tight_layout()
plt.show()
